# %%
from surprise import BaselineOnly
from surprise import Dataset
from surprise import Reader
from surprise import accuracy
from surprise import SVD
from surprise.model_selection import train_test_split
from surprise.model_selection import KFold
from surprise.model_selection import cross_validate
from surprise.model_selection import GridSearchCV
import pandas as pd
import os
import numpy as np

# %%
file_path = os.getcwd()+'/users.csv'
svd_path = '/home/shahanex/Downloads/SVD_2.csv'
track_path = '/home/shahanex/Desktop/RecommendationProject/Spoitfy-Music-Recommender/tracks_with_cluster.csv'

# %%
svd = pd.read_csv(svd_path)
tracks = pd.read_csv(track_path)

# %%
uid = 1

row = svd.loc[uid-1]

tracks.sort_values(by='popularity', ascending=False)
# Out:
#         Unnamed: 0                      id  \
# 93802        93802  4iJyoBOLtHqaGxP12qzhQI
# 93803        93803  7lPN2DXiMsVn7XUKtOW1CS
# 93804        93804  3Ofmpyhv5UAQ70mENzB277
# 92810        92810  5QO79kh1waicV47BqGRL3g
# 92811        92811  6tDDoYIxWvMLTdKpjFkc1B
# ...            ...                     ...
# 23410        23410  0sniGbmm1sjg51BxO6AHD4
# 23409        23409  0sk8KA96i9MIU8St2nmbIx
# 23408        23408  0sdkzsc3WtZIrSi1nNyl7v
# 23407        23407  0s6h3lMdJsWkpUAW6xC7m3
# 444118      444118  4Jb8iDtQk8QgFFMHApIrgK
#
#                                               name  popularity  duration_ms  \
# 93802       Peaches (feat. Daniel Caesar & Giveon)         100       198082
# 93803                              drivers license          99       242014
# 93804                       Astronaut In The Ocean          98       132780
# 92810                              Save Your Tears          97       215627
# ...

# %%
track = []

for i in range(1, 11):
    artist = row.tolist()[i].split("'")[1]
    track.append(tracks[tracks['artists'].str.contains(artist)]['id'].tolist()[:1][0])
        

print(track)
# Out:
# ['6l4wMAXzI8RxIysQMYZY0w', '0PicuPCfXDJyyRtOR1ukGW', '4wseRLZqlHX0svfp0btZD5', '0qi4b1l0eT3jpzeNHeFXDT', '1ohwrBQrxIlqMYfkoYERiN', '0nbuX7OZkEY5agMkpr98wS', '5YeQoMo5py82YmqXMTjM5S', '3ij7wTT8OOy8MhkT6AS5aS', '1iv0lBFv1ybeLlSz83uB81', '5EWPGh7jbTNO2wakv8LjUI']
