# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel
import pandas as pd
import os
import numpy as np

# %%
track_path = '/home/shahanex/Desktop/RecommendationProject/Data/tracks.csv'
tracks = pd.read_csv(track_path)

# %%
tracks.tail(30)
# Out:
#                             id                         name  popularity  \
# 586642  44tvGaqisGSy4Qy45vd0CF  Thousand Pieces (FYHYM2019)           1
# 586643  1932nBdtEgMpDGkpl93cS4     Saving Angel (FYHYM2019)           1
# 586644  4cB00WOFuQFLoDpnydcx8c                          7UP          62
# 586645  44r4zta6P9flkhKaVnbsvG                       Freaks          70
# 586646  0F2muCxmWhi7NfY9poM0KZ             至少我還記得 - 天堂的微笑插曲          44
# 586647  0mDsJ6a7qY3DWbCAHancPj              King - Acoustic           2
# 586648  1PFGNasip0OTl24ZHPT6iy                       你一定要幸福          49
# 586649  0MmaEacabpK8Yp3Mdeo5uY                          下雨天          50
# 586650  1uviKYHZuM4uINK33F7sCt           Fix It to Break It          70
# 586651  7s5bBky7QncZeb8XmceSOH                          最好是          49
# 586652  1fXmDeiCb3ABt5CzkMxp4u                    Lotus Inn          63
# 586653  6jMIzxLw7QDtvfo9XYFjKy                       最嚮往的地方          48
# 586654  6sHxpnCerm9M6A5zaFFNfs                         Gone          66
# 586655  2nt8dbNspSCB9p7YgLIblV                   执迷不悟 - DJ版          50
# 586656  65hdygJXXOBGKS76EKvxth                        醒不来的梦          50
# 586657  1dKxf4Ht2SsKLyXfSDJAgy             The Cutest Puppy          67
# 586658  6IGuPIQaRd7PPsKO35N1dv                           奉劝          48
# 586659  7JWoMpoxEl3pZ2CLZxM6ms                         天空之外          49
# 586660  4SMp3hkQV64IoaaKsBQoBo                    Edelweiss          65
# 586661  27kcZEJvhkb1rzZS9gCpdA        remember the mornings          67
# 586662  4Zp3rm12p5PiHToYJflmyy                   Meet Again          57
# 586663  4ow9HehIdFii1cggylW2k0                   四季予你 - DJ版          47
# 586664  1Kzjk1EyngBcP4T8x3fyqv     同行 (新加坡電視劇《愛...沒有距離》主題曲)          43
# 586665  0SjsIzJkZfDU7wlcdklEFR            John Brown's Song          66
# 586666  1ZwZsVZUiyFwIHMNpI3ERt                   Skyscraper           4
# 586667  5rgu12WBIHQtvej2MdHSH0                          云与海          50
# 586668  0NuWgxEp51CutD2pJoF4OM                        blind          72
# 586669  27Y1N4Q4U3EfDU5Ubw8ws2    What They'll Say About Us          70
# 586670  45XJsGpFTyzbzeWK8VzR8S              A Day At A Time          58
# 586671  5Ocn6dZ3BJFPWh4ylwFXtn             Mar de Emociones          38
#
#         duration_ms  explicit                                   artists  \
# 586642        83477         0  ['A & Z', 'Claudiu Adam', 'Clara Yates']
# 586643       125216         0                    ['RAM', 'Stine Grove']
# 586644       203555         0                          ['Boy In Space']
# 586645       174800         0                         ['Jordan Clarke']
# 586646       304800         0                             ['Eric Chou']
# 586647       243987         0                         ['Years & Years']
# 586648       290636         0                                    ['开开']
# 586649       265846         0                                    ['芝麻']
# 586650       198799         0                          ['Clinton Kane']
# 586651       272771         0                                ['JJ Lin']
# 586652       195868         0                          ["Why Don't We"]
# 586653       232784         0                                ['JJ Lin']
# 586654       205462         0                            ['Blake Rose']
# 586655       245625         0                                   ['小乐哥']
# 586656       232297         0                                   ['回小仙']
# 586657        82500         0                        ['Laureen Conrad']
# 586658       254028         0                                    ['En']
# 586659       367192         0                                   ['解语花']
# 586660       123500         0                       ['Ludovico Sagese']
# 586661       202355         0                          ['Clinton Kane']
# 586662       273587         0                            ['KIMSEJEONG']
# 586663       156393         0                              ['程響', '阿卓']
# 586664       205238         0                           ['Boon Hui Lu']
# 586665       185250         0                        ['Gregory Oberle']
# 586666       106002         0                           ['Emilie Chin']
# 586667       258267         0                               ['阿YueYue']
# 586668       153293         0                            ['ROLE MODEL']
# 586669       187601         0                               ['FINNEAS']
# 586670       142003         0           ['Gentle Bones', 'Clara Benin']
# 586671       214360         0                             ['Afrosound']
#
#                                                id_artists release_date  \
# 586642  ['22y1A8uijPBYxDPOrMWZPb', '78JtIs2G2CpfOZadEs...   2020-01-05
# 586643  ['4f0a5IgkYFHFts5Z9N9SDX', '51GkQKgac6wqdicVA2...   2020-01-05
# 586644                         ['0xu4jAQQv7ZAqvFGdc9HgP']   2019-05-30
# 586645                         ['14Y3trk7LaslSFTk1G35rx']   2019-02-25
# 586646                         ['5fEQLwq1BWWQNR8GzhOIvi']   2019-01-10
# 586647                         ['5vBSrE1xujD2FXYRarbAXc']   2020-06-26
# 586648                         ['5luSIDrs6oR8T858ZQYb1B']   2020-07-01
# 586649                         ['5VGgFE9nPgMfEnYiPT5J2B']   2020-02-25
# 586650                         ['7okSU80WTrn4LXlyXYbX3P']   2020-03-27
# 586651                         ['7Dx7RhX0mFuXhCOUgB01uM']   2020-10-20
# 586652                         ['2jnIB6XdLvnJUeNTy5A0J2']   2020-12-04
# 586653                         ['7Dx7RhX0mFuXhCOUgB01uM']   2020-10-20
# 586654                         ['7wLyGTO9vUS7ndlq4BvBGe']   2020-02-07
# 586655                         ['7LadOFiUVrFL5Ancq9RLtP']   2020-09-22
# 586656                         ['27kWsk6mk6DeqQhdOHsyej']   2020-09-29
# 586657                         ['7vgGpuiXdNlCmc994PlMlz']   2020-10-30
# 586658                         ['1SZdTuxme3mOk0D9pUFrET']   2020-06-30
# 586659                         ['5SWFVqjJ5POFRF6cudSL3X']   2020-01-19
# 586660                         ['1dygDSkQGQOfq1ZdChpOCs']   2020-02-14
# 586661                         ['7okSU80WTrn4LXlyXYbX3P']   2020-11-27
# 586662                         ['1lFLniFTaPjYCtQZvDXpqu']   2020-12-20
# 586663  ['7nKA1c1Qn6nI0XA8yburf3', '7g8hOWXtGS16J30CMU...   2020-12-29
# 586664                         ['6PWJWwEm8BSBFAIAUWlwe4']   2020-03-03
# 586665                         ['4MxqhahGRT4BPz1PilXGeu']   2020-03-20
# 586666                         ['4USdOnfLczwUglA3TrdHs2']   2020-02-08
# 586667                         ['1QLBXKM5GCpyQQSVMNZqrZ']   2020-09-26
# 586668                         ['1dy5WNgIKQU6ezkpZs4y8z']   2020-10-21
# 586669                         ['37M5pPGs6V1fchFJSgCguX']   2020-09-02
# 586670  ['4jGPdu95icCKVF31CcFKbS', '5ebPSE9YI5aLeZ1Z2g...   2021-03-05
# 586671                         ['0i4Qda0k4nf7jnNHmSNpYv']   2015-07-01
#
#         danceability  energy  key  loudness  mode  speechiness  acousticness  \
#
# 586655          0.000121    0.2140   0.9310  128.003               4
# 586656          0.000000    0.3940   0.4710  108.012               4
# 586657          0.973000    0.1080   0.8900   68.619               4
# 586658          0.000000    0.2020   0.3800  138.085               4
# 586659          0.004830    0.4200   0.2430  124.990               4
# 586660          0.959000    0.1360   0.4480   99.873               3
# 586661          0.000000    0.1100   0.3420  149.447               4
# 586662          0.000000    0.0926   0.2410  135.814               4
# 586663          0.002340    0.3020   0.9080  140.026               4
# 586664          0.000000    0.1330   0.3950  126.070               4
# 586665          0.961000    0.1110   0.3860   63.696               3
# 586666          0.856000    0.1040   0.2150  120.113               4
# 586667          0.000000    0.0648   0.2110  131.896               4
# 586668          0.000297    0.0924   0.6860  150.091               4
# 586669          0.000150    0.0874   0.0663  145.095               4
# 586670          0.000003    0.3050   0.4380   90.029               4
# 586671          0.000000    0.2640   0.9750  112.204               4

# %%
tfidf = TfidfVectorizer(stop_words='english')

#Replace NaN with an empty string
tracks['name'] = tracks['name'].fillna('')

tracks = tracks.head(25000)

#Construct the required TF-IDF matrix by fitting and transforming the data
tfidf_matrix = tfidf.fit_transform(tracks['name'])

#Output the shape of tfidf_matrix
tfidf_matrix.shape

# %%
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

# %%
indices = pd.Series(tracks.index, index=tracks['name']).drop_duplicates()

# %%
def get_recommendations(title, cosine_sim=cosine_sim):
    idx = indices[title]

    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:11]

    track_indices = [i[0] for i in sim_scores]
    print(tracks['name'].iloc[track_indices].tolist())
    return tracks['id'].iloc[track_indices].tolist()

# %%
get_recommendations("Go Home")

# %%
# Returns the list top 3 elements or entire list; whichever is more.
def get_list(x):
    if isinstance(x, list):
        names = [i['name'] for i in x]
        #Check if more than 3 elements exist. If yes, return only first three. If no, return entire list.
        if len(names) > 3:
            names = names[:3]
        return names

    #Return empty list in case of missing/malformed data
    return []

# %%
def clean_data(x):
    if isinstance(x, list):
        return [str.lower(i.replace(" ", "")) for i in x]
    else:
        #Check if director exists. If not, return empty string
        if isinstance(x, str):
            return str.lower(x.replace(" ", ""))
        else:
            return ''

# %%
features = ['artists', 'energy', 'loudness', 'instrumentalness']
#features = ['artists']
for feature in features:
    tracks[feature] = tracks[feature].apply(clean_data)
#     tracks[feature] = tracks[feature].apply(eval)

# %%
tracks.head(3)

# %%
def cos_sim(a,b):
    dot_product = np.dot(a,b)
    norm_a = linalg.norm(a)
    norm_b = linalg.norm(b)
    return dot_product/(norm_a*norm_b)

# %%
https://towardsdatascience.com/how-to-build-an-amazing-music-recommendation-system-4cce2719a572

# %%
from collections import defaultdict
from scipy.spatial.distance import cdist
import difflib
from sklearn.pipeline import Pipeline 
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# %%
song_cluster_pipeline = Pipeline([('scaler', StandardScaler()), 
                                  ('kmeans', KMeans(n_clusters=20, 
                                   verbose=2, n_jobs=4))],verbose=True)
X = tracks.select_dtypes(np.number)
number_cols = list(X.columns)
song_cluster_pipeline.fit(X)
song_cluster_labels = song_cluster_pipeline.predict(X)
tracks['cluster_label'] = song_cluster_labels
# Out:
# [Pipeline] ............ (step 1 of 2) Processing scaler, total=   0
# Iteration 31, inertia 4134677.128119346
# Iteration 32, inertia 4134337.5358133633
# Iteration 33, inertia 4134064.6436241935
# Iteration 34, inertia 4133831.609165939
# Iteration 35, inertia 4133628.449453543
# Iteration 36, inertia 4133456.932365165
# Iteration 37, inertia 4133326.7211629525
# Iteration 38, inertia 4133219.7810520157
# Iteration 39, inertia 4133131.247536544
# Iteration 40, inertia 4133062.343474966
# Iteration 41, inertia 4133011.6859185253
# Iteration 42, inertia 4132968.3261713986
# Iteration 43, inertia 4132931.079909495
# Iteration 44, inertia 4132900.675090126
# Iteration 45, inertia 4132879.496619016
# Iteration 46, inertia 4132862.492761195
# Iteration 47, inertia 4132848.275408494
# Iteration 48, inertia 4132838.0384066873
# Iteration 49, inertia 4132829.6034998903
# Iteration 50, inertia 4132822.9446180635
# Iteration 51, inertia 4132816.325483617
# Iteration 52, inertia 4132809.65341065
# Converged at iteration 52: center shift 9.168570373314443e-05 within tolerance 0.00010000000000000265.
# [Pipeline] ............ (step 2 of 2) Processing kmeans, total= 1.0min

# %%
tracks.to_csv('tracks_with_cluster.csv')

# %%
tracks.head()

# %%
from sklearn.decomposition import PCA

pca_pipeline = Pipeline([('scaler', StandardScaler()), ('PCA', PCA(n_components=2))])
song_embedding = pca_pipeline.fit_transform(X)
projection = pd.DataFrame(columns=['x', 'y'], data=song_embedding)
projection['title'] = tracks['name']
projection['cluster'] = tracks['cluster_label']

# %%
import plotly.express as px
fig = px.scatter(projection, x='x', y='y', color='cluster', hover_data=['x', 'y', 'title'])
fig.show()

# %%
number_cols = ['time_signature','duration_ms','popularity','valence', 'acousticness', 'danceability',  'energy', 'instrumentalness', 'explicit','key', 'liveness', 'loudness', 'mode', 'speechiness', 'tempo']

# %%
def get_song_data(song, spotify_data):
    
    """
    Gets the song data for a specific song. The song argument takes the form of a dictionary with 
    key-value pairs for the name and release year of the song.
    """
    
    try:
        song_data = spotify_data[(spotify_data['name'] == song['name']) ].iloc[0]
        return song_data
    
    except IndexError:
        return find_song(song['name'])

# %%
def get_mean_vector(song_list, spotify_data):
  
    """
    Gets the mean vector for a list of songs.
    """
    
    song_vectors = []
    
    for song in song_list:
        song_data = get_song_data(song, spotify_data)
        if song_data is None:
            print('Warning: {} does not exist in Spotify or in database'.format(song['name']))
            continue
        song_vector = song_data[number_cols].values
        song_vectors.append(song_vector)  
    
    song_matrix = np.array(list(song_vectors))
    return np.mean(song_matrix, axis=0)

# %%
def flatten_dict_list(dict_list):
   
    """
    Utility function for flattening a list of dictionaries.
    """
    
    flattened_dict = defaultdict()
    for key in dict_list[0].keys():
        flattened_dict[key] = []
    
    for dictionary in dict_list:
        for key, value in dictionary.items():
            flattened_dict[key].append(value)
            
    return flattened_dict

# %%
def recommend_songs(song_id, n_songs=10):
  
    """
    Recommends songs based on a list of previous songs that a user has listened to.
    """
    spotify_data = tracks
    song_name = tracks.loc[tracks.id == song_id, 'name']
    song_list = [{'name': song_name.values[0]}]
    song_dict = flatten_dict_list(song_list)
    
    song_center = get_mean_vector(song_list, spotify_data)
    scaler = song_cluster_pipeline.steps[0][1]
    scaled_data = scaler.transform(spotify_data[number_cols])
    scaled_song_center = scaler.transform(song_center.reshape(1, -1))
    distances = cdist(scaled_song_center, scaled_data, 'cosine')
    index = list(np.argsort(distances)[:, :n_songs][0])
    
    rec_songs = spotify_data.iloc[index]
    rec_songs = rec_songs[~rec_songs['name'].isin(song_dict['name'])]
    return rec_songs['id'].tolist()

# %%
recommend_songs('4iJyoBOLtHqaGxP12qzhQI')
# Out:
# ['2uwnP6tZVVmTovzX5ELooy',
#  '6Im9k8u9iIzKMrmV7BWtlF',
#  '5QO79kh1waicV47BqGRL3g',
#  '2G7V7zsVDxg1yRsu7Ew9RJ',
#  '0NTMtAO2BV4tnGvw9EgBVq',
#  '0WZFN4E8HrmGUU0EMyKQ8c',
#  '7FYH5AW3bVfZHJIQpq3UOA',
#  '6Ph8QwsRfZunN5e1GGBIqa']

# %%
df = pd.read_csv('/home/shahanex/Downloads/popularity_sorted_tracks_ids.txt', sep='\n', header = None)
df.columns = ['input']

# %%
df.head()
# Out:
#                     input
# 0  4iJyoBOLtHqaGxP12qzhQI
# 1  2XIc1pqjXV3Cr2BQUGNBck
# 2  0lx2cLdOt3piJbcaXIV74f
# 3  3aQem4jVGdhtg116TmJnHz
# 4  4saklk6nie3yiGePpBwUoc

# %%
songs = df['input'].tolist()
output = {}
outputs = []
for song in songs:
    k = recommend_songs(song)
    output.update( {song : k})

# %%
output
# Out:
# {'4iJyoBOLtHqaGxP12qzhQI': ['2uwnP6tZVVmTovzX5ELooy',
#   '6Im9k8u9iIzKMrmV7BWtlF',
#   '5QO79kh1waicV47BqGRL3g',
#   '2G7V7zsVDxg1yRsu7Ew9RJ',
#   '0NTMtAO2BV4tnGvw9EgBVq',
#   '0WZFN4E8HrmGUU0EMyKQ8c',
#   '7FYH5AW3bVfZHJIQpq3UOA',
#   '6Ph8QwsRfZunN5e1GGBIqa'],
#  '2XIc1pqjXV3Cr2BQUGNBck': ['266Vb7ItE3o1q8HdJ9QOvn',
#   '4TsmezEQVSZNNPv5RJ65Ov',
#   '1ZY1PqizIl78geGM4xWlEA',
#   '5G6jHSoLrzhtPBhS2gMvfW',
#   '0Y2EhhpZTKChZNerxIt6T9',
#   '5u1n1kITHCxxp8twBcZxWy',
#   '6Xgq7MvZiet0hVi3KaDSgJ',
#   '1hHR1visLei5uOWSDxPppA',
#   '6xf2KSaajcQyIUNESVYhzO'],
#  '0lx2cLdOt3piJbcaXIV74f': ['5uCax9HTNlzGybIStD3vDh',
#   '1dGr1c8CrMLDpV6mPbImSI',
#   '1RMJOxR6GRPsBHL8qeC2ux',
#   '70w1mwTod6NgCNV6e7ZlIQ',
#   '1Pw5C4N6Fn5E4mGCxmbbVa',
#   '6gcQJ6W4H89xkQFm63gcsB',
#   '2IOFZdYYkFxEHVz1w34PoL'],
#  '3aQem4jVGdhtg116TmJnHz': ['39Yp9wwQiSRIDOvrVg7mbk',
#   '7AQim7LbvFVZJE3O8TYgf2',
#   '4IowQDUOzUvNtp72HMDcKO',
#   '0YP8kt3sAYTj6eEyesreQH',
#   '7fBv7CLKzipRk6EC6TWHOB',
#   '01Lr5YepbgjXAWR9iOEyH1',
#   '02UJ1sCanP94fS2MdsWafh',
#   '4KiFqaxjnmVm0gyIPIRRgH',
#   '4jvjzW7Hm0yK4LvvE0Paz9'],
#  '4saklk6nie3yiGePpBwUoc': ['1HbENaSKc0V5GK4M5xOQT3',
#   '7x5eu2rXvHr6GpJJgtXjiP',
#   '2IArdEJzafXKo4xY565GWM',
#   '4hqHnqklx86ToYstEzu6Bb',
#   '7q4XWr64sG7pApfy3Hgi8E',
#   '5KJ3obqoLBE4UEHFsX6vO1',
#   '1RJcgYDr7DwOm95bSZpmYf',
#   '1DNSiaZ6wHGZbRmZn75M1l',
#   '4zh1qHlC0kyduYAstMO7im'],
#  '285pBltuF7vW8TeWk8hdRR': ['7ge7BHazYbVKi8qyZUX1Bm',
#   '7vgTNTaEz3CsBZ1N4YQalM',
#   '7E2C5rBLpCKwQlhJPVFBRS',
#   '27NV2KxoQ8WuLMqlTDI61F',
#   '5tz69p7tJuGPeMGwNTxYuV',
#   '3eekarcy7kvN4yt5ZFzltW',
#   '7eqoqGkKwgOaWNNHx90uEZ',
#   '31I3Rt1bPa2LrE74DdNizO',
#   '14SaZBTjxlorHJQxXh01Hu'],
#  '5QO79kh1waicV47BqGRL3g': ['2bJvI42r8EF3wxjOuDav4r',
#   '5sNESr6pQfIhL3krM8CtZn',
#   '2SL6oP2YAEQbqsrkOzRGO4',
#   '4iJyoBOLtHqaGxP12qzhQI',
#   '7dyluIqv7QYVTXXZiMWPHW',
#   '15yuvKhcoEtV5KwKxqHSwa',
#   '1LmN9SSHISbtp9LoaR5ZVJ',
#   '5JAYDuLRkODlVt6dgoalKk'],
#  '35mvY5S1H3J2QZyna3TFe0': ['1T4U8Q2DRfs6OUg8DEsRZf',
#   '1tLV0GD0WXQ1Z8BKOQscti',
#   '7LGWmZaoS7jZJ5tEi9EcDi',
#   '1vvBUZseJ7fwYPX1NedOLd',
#   '6PqRRt5BCxO6tay5Nry0dj',
#   '29TPjc8wxfz4XMn21O7VsZ',
#   '20McUFi8KCIVdNDLrkTDuZ',
#   '5uEYRdEIh9Bo4fpjDd4Na9',
#   '17vGPZ5EsdvtgAOCD4FLWI'],
#  '35UUpTmrcFXNIVIN26ujXl': ['3w3y8KPTfNeOKPiqUTakBh',
#   '3gD4J3RUHy4OUuZ3qAiaiG',
#   '5Jm4w8jmPEBTLjI9vH4fXo',
#   '3axkNosdVQLZiq1HakuGhc',
#   '2CkHE54EH44Qj945ynQRw7',
#   '2ktoFujjJtantyMoVdBJlX',
#   '0cqRj7pUJDkTCEsJkx8snD',
#   '5Kpg1A7BOHpBbaT3H3xqd3',
#   '2fTsFCKRFQ5M0igJgabnLA']}

# %%
df1 = pd.DataFrame.from_dict(output, orient='index')

# %%
df1.to_csv('content_based.csv')
